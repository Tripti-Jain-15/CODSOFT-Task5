# %%
# Import required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# # Load the dataset

# %%
c_data = pd.read_csv("D:\Download\creditcard\creditcard.csv")
c_data
# Out:
#             Time         V1         V2        V3        V4        V5
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321  \
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22
# ...

# %%
c_data.shape
# Out:
# (284807, 31)

# %%
c_data.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  \
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25
# ...

# %%
c_data.tail(10)
# Out:
#             Time         V1         V2        V3        V4        V5
# 284797  172782.0  -0.241923   0.712247  0.399806 -0.463406  0.244531  \
# 284798  172782.0   0.219529   0.881246 -0.635891  0.960928 -0.152971
# 284799  172783.0  -1.775135  -0.004235  1.189786  0.331096  1.196063
# 284800  172784.0   2.039560  -0.175233 -1.196825  0.234580 -0.008713
# 284801  172785.0   0.120316   0.931005 -0.546012 -0.745097  1.130314
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22
# 284797 -1.343668  0.929369 -0.206210  0.106234  ... -0.228876 -0.514376  \
# ...

# %%
c_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
c_data.describe()
# Out:
#                 Time            V1            V2            V3            V4
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  \
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  \
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# # Handling missing data

# %%
c_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
c_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# 0 = Normal Transaction
# 1 = Fraudulent Transaction

# %%
# Separating both data
legit = c_data[c_data.Class == 0]
fraud = c_data[c_data.Class == 1]

# %%
legit.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
legit['Amount'].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Compare the values of both transaction
c_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453  \
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235  \
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131  \
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n = 492)

# %%
df = pd.concat([legit_sample,fraud],axis = 0)

# %%
df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6
# 264178  161304.0  1.517498 -1.770624  0.305586  0.662373 -1.455180  1.455280  \
# 132081   79845.0  1.058670 -0.306760  0.192572  0.184956 -0.695990 -1.122597
# 240158  150455.0  1.425496 -1.230426 -0.664877  0.606260 -1.005644 -0.699735
# 100701   67595.0  1.178768 -0.040746  1.028326  0.648021 -1.083981 -0.942981
# 63209    50608.0 -0.988271 -0.932178  1.717482 -1.694737  0.957518 -1.149287
#
#               V7        V8        V9  ...       V21       V22       V23
# 264178 -1.560278  0.627075  2.513248  ...  0.188875  0.551297 -0.009623  \
# 132081  0.191993 -0.252153  0.167013  ... -0.164950 -0.784245  0.016049
# 240158 -0.084252 -0.212680  1.297308  ...  0.409710  0.729161 -0.138531
# 100701 -0.366494 -0.057827  0.466191  ... -0.068015 -0.256884  0.133234
# 63209   0.649517 -1.029868 -0.496942  ...  0.010248  0.694859 -0.621559
#
# ...

# %%
df.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494  \
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419  \
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5
# Class
# 0      94631.800813 -0.038626 -0.048650  0.015496 -0.087169  0.005356  \
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21
# Class                                          ...
# 0      0.041486  0.017944  0.045519  0.047350  ... -0.048278 -0.019265  \
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23      V24       V25       V26       V27       V28
# Class
# 0     -0.021421  0.013138  0.02663 -0.033106  0.017315 -0.003427  0.013766  \
# 1      0.014049 -0.040308 -0.10513  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       87.536463
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# # Visualization of data

# %%
sns.countplot(x='Class', data=c_data)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
corr = df.corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %% [markdown]
# # Splitting the data

# %%
X = df.drop('Class', axis = 1)
y = df['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 30) (688, 30) (296, 30)

# %% [markdown]
# # Normalizing data

# %%
# Perform feature normalization
scaler = StandardScaler()
X_normalized = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_normalized,y,test_size=0.2, random_state=24)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
# Oversampling using SMOTE
smote = SMOTE(sampling_strategy = 1.0, random_state = 24)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
# Undersampling using Random Undersampling
rus = RandomUnderSampler(sampling_strategy=1.0, random_state=42)
X_train_rus, y_train_rus = rus.fit_resample(X_train, y_train)

# %%
# Train a logistic regression model using oversampled data
model_smote = LogisticRegression()
model_smote.fit(X_train_smote, y_train_smote)
# Out:
# LogisticRegression()

# %%
# Train a logistic regression model using undersampled data
model_rus = LogisticRegression()
model_rus.fit(X_train_rus, y_train_rus)
# Out:
# LogisticRegression()

# %%
# Evaluate models
y_pred_smote = model_smote.predict(X_test)
y_pred_rus = model_rus.predict(X_test)

# %%
print("Results using SMOTE:")
print(classification_report(y_test, y_pred_smote))
# Out:
# Results using SMOTE:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95        96
#            1       0.97      0.93      0.95       101
#
#     accuracy                           0.95       197
#    macro avg       0.95      0.95      0.95       197
# weighted avg       0.95      0.95      0.95       197

# %%
print("Results using Random Undersampling:")
print(classification_report(y_test, y_pred_rus))
# Out:
# Results using Random Undersampling:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95        96
#            1       0.97      0.93      0.95       101
#
#     accuracy                           0.95       197
#    macro avg       0.95      0.95      0.95       197
# weighted avg       0.95      0.95      0.95       197

# %%
# Model Evaluation

# %%
# Accuracy on training data
X_train_pred = model_smote.predict(X_train)
train_acc = accuracy_score(X_train_pred,y_train)
train_acc
# Out:
# 0.951715374841169

# %%
# Accuracy on testing data
X_test_pred = model_smote.predict(X_test)
test_acc = accuracy_score(X_test_pred, y_test)
test_acc
# Out:
# 0.949238578680203

# %%
# Random Forest Classifier

# %%
rf_model = RandomForestClassifier()

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rf_ypred = rf_model.predict(X_test)

# %%
acc1 = accuracy_score(y_test,rf_ypred)
print("Accuracy is ",acc1)
# Out:
# Accuracy is  0.9441624365482234

# %%
print(classification_report(y_test,rf_ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94        96
#            1       0.96      0.93      0.94       101
#
#     accuracy                           0.94       197
#    macro avg       0.94      0.94      0.94       197
# weighted avg       0.94      0.94      0.94       197

# %%
from sklearn .metrics import precision_score, confusion_matrix
from sklearn.metrics import recall_score, f1_score

# %%
LABELS = ['legit','fraud']
conf_matrix = confusion_matrix(y_test,X_test_pred)
sns.heatmap(conf_matrix, xticklabels = LABELS,
           yticklabels = LABELS, annot = True, fmt = "d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
# Precision Score

# %%
prec = precision_score(y_test, X_test_pred)
print("Precision is {}".format(prec))
# Out:
# Precision is 0.9690721649484536

# %%
# Recall Score

# %%
rec = recall_score(y_test, X_test_pred)
print("Recall score is {}".format(rec))
# Out:
# Recall score is 0.9306930693069307

# %%
# F1 Score

# %%
f1 = f1_score(y_test, X_test_pred)
print("F1 score is {}".format(f1))
# Out:
# F1 score is 0.9494949494949495
